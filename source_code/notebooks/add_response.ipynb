# %%
import pandas as pd

# %%
dataset = pd.read_csv("../../mutational/mutational.csv")
encoded = pd.read_csv("../../results_demo/mutational/Properties/Group_7/Group_7_encoding.csv")

# %%
encoded
# Out:
#          name        p_0         p_1         p_2         p_3         p_4  \
# 0     p.R518X  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 1     p.Y515X  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 2     p.R514X  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 3     p.F512X  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 4     p.S511X  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# ...       ...        ...         ...         ...         ...         ...
# 2336   p.S19E  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 2337   p.S19D  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 2338   p.S19C  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 2339   p.S19A  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
# 2340      p.=  16.043669 -122.668822 -122.668822 -122.668822 -122.668822
#
#              p_5       p_6       p_7       p_8  ...     p_795      p_796  \
# ...

# %%
encoded.insert(1,"response",dataset["response"])

# %%
encoded
# Out:
#          name  response        p_0         p_1         p_2         p_3  \
# 0     p.R518X -2.878625  16.043669 -122.668822 -122.668822 -122.668822
# 1     p.Y515X -0.842639  16.043669 -122.668822 -122.668822 -122.668822
# 2     p.R514X -1.385470  16.043669 -122.668822 -122.668822 -122.668822
# 3     p.F512X -2.513003  16.043669 -122.668822 -122.668822 -122.668822
# 4     p.S511X -0.925150  16.043669 -122.668822 -122.668822 -122.668822
# ...       ...       ...        ...         ...         ...         ...
# 2336   p.S19E -1.436496  16.043669 -122.668822 -122.668822 -122.668822
# 2337   p.S19D -1.353322  16.043669 -122.668822 -122.668822 -122.668822
# 2338   p.S19C -1.169052  16.043669 -122.668822 -122.668822 -122.668822
# 2339   p.S19A  0.060673  16.043669 -122.668822 -122.668822 -122.668822
# 2340      p.=  0.000000  16.043669 -122.668822 -122.668822 -122.668822
#
#              p_4         p_5       p_6       p_7  ...     p_795      p_796  \
# ...

# %%
encoded.to_csv("../../results_demo/mutational/Properties/Group_7/properties-Group_7-mutational.csv")
