# %%
import os
import pandas as pd

# %%
dataset = {
    0 : "absorption",
    1 : "enantioselectivity",
    2 : "localization",
    3 : "T50"
}
method = {
    0:"FFT",
    1:"NLP",
    2:"Properties"
}
bioembedding = {
    0:"bepler",
    1:"esm",
    2:"fasttext",
    3:"plus_rnn",
    4:"prottrans"
}
distances = {
    1 : "Euclidean",
    2 : "Braycurtis",
    3 : "Canberra",
    4 : "Chebyshev",
    5 : "Cityblock",
    6 : "Correlation",
    7 : "Cosine",
    8 : "Minkowski",
    9 : "Hamming"
}
absorption_parent = {
    0 : "sequence_40826",
}
localization_parent = {
    0 : "sequence_51016",
    1 : "sequence_51170",
    2 : "sequence_32130",
}
enantio_parent = {
    0 : "sequence_47787",
}
t50_parent = {
    0 : "sequence_53082",
    1 : "sequence_19402",
    2 : "sequence_20054",
}

# %%
for a in range (0,4): #Se elije el dataset
    for b in range(0,3): #Se elije el metodo de representacion numerica
        if b==1: #Si es NLP entra a este if
            for c in range(0,5): #Cual de los 5 metodos de PLM
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/"+bioembedding[c]+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/"+bioembedding[c]+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    Cluster = pd.DataFrame()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                    Cluster.to_csv("../../results_demo/"+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d]+"/cluster_unite_without.csv")
                    print("Cluster unite for "+dataset[a]+"/NLP/"+bioembedding[c]+"/"+distances[d])
        if b == 0:
            for c in range(0,8):
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    Cluster = pd.DataFrame()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                    Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/cluster_unite_without.csv")
                    print("Cluster unite for "+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d])
        if b == 2:
            for c in range(0,8):
                for d in range(1,10): #Se elije la distancia
                    df_profiles = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/generated_profiles.csv")
                    df_distances = pd.read_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/distance_estimator.csv")
                    profiles = df_profiles.profile.unique()
                    Cluster = pd.DataFrame()
                    for f in range(0,len(profiles)): #para entrar a cada perfil
                        df_f = (df_profiles["profile"] == profiles[f])
                        clust_aux = df_profiles[df_f]
                        if a == 0: #Absorption
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==absorption_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 1: #Enantioselectivity
                            for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                df_filter = df_distances[(df_distances.id_seq1==enantio_parent[0]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                Cluster = pd.concat([Cluster,df_filter])
                        if a == 2: #Localization
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==localization_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                        if a == 3: #T50
                            for parent in range(0,3):
                                for g in range(0,len(clust_aux.index)): #Esto para elegir la o las nativas
                                    df_filter = df_distances[(df_distances.id_seq1==t50_parent[parent]) & (df_distances.id_seq2 == clust_aux.iloc[g][0])]
                                    df_filter.insert(5,"profile",profiles[f],allow_duplicates=False)
                                    Cluster = pd.concat([Cluster,df_filter])
                    Cluster.to_csv("../../results_demo/"+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d]+"/cluster_unite_without.csv")
                    print("Cluster unite for "+dataset[a]+"/"+method[b]+"/Group_"+str(c)+"/"+distances[d])
# Out:
# Cluster unite for absorption/FFT/Group_0/Euclidean
# Cluster unite for absorption/FFT/Group_0/Braycurtis
# Cluster unite for absorption/FFT/Group_0/Canberra
# Cluster unite for absorption/FFT/Group_0/Chebyshev
# Cluster unite for absorption/FFT/Group_0/Cityblock
# Cluster unite for absorption/FFT/Group_0/Correlation
# Cluster unite for absorption/FFT/Group_0/Cosine
# Cluster unite for absorption/FFT/Group_0/Minkowski
# Cluster unite for absorption/FFT/Group_0/Hamming
# Cluster unite for absorption/FFT/Group_1/Euclidean
# Cluster unite for absorption/FFT/Group_1/Braycurtis
# Cluster unite for absorption/FFT/Group_1/Canberra
# Cluster unite for absorption/FFT/Group_1/Chebyshev
# Cluster unite for absorption/FFT/Group_1/Cityblock
# Cluster unite for absorption/FFT/Group_1/Correlation
# Cluster unite for absorption/FFT/Group_1/Cosine
# Cluster unite for absorption/FFT/Group_1/Minkowski
# Cluster unite for absorption/FFT/Group_1/Hamming
# Cluster unite for absorption/FFT/Group_2/Euclidean
# Cluster unite for absorption/FFT/Group_2/Braycurtis
# Cluster unite for absorption/FFT/Group_2/Canberra
# Cluster unite for absorption/FFT/Group_2/Chebyshev
# Cluster unite for absorption/FFT/Group_2/Cityblock
# Cluster unite for absorption/FFT/Group_2/Correlation
# Cluster unite for absorption/FFT/Group_2/Cosine
# Cluster unite for absorption/FFT/Group_2/Minkowski
# Cluster unite for absorption/FFT/Group_2/Hamming
# Cluster unite for absorption/FFT/Group_3/Euclidean
# Cluster unite for absorption/FFT/Group_3/Braycurtis
# Cluster unite for absorption/FFT/Group_3/Canberra
# Cluster unite for absorption/FFT/Group_3/Chebyshev
# Cluster unite for absorption/FFT/Group_3/Cityblock
# Cluster unite for absorption/FFT/Group_3/Correlation
# Cluster unite for absorption/FFT/Group_3/Cosine
# Cluster unite for absorption/FFT/Group_3/Minkowski
# Cluster unite for absorption/FFT/Group_3/Hamming
# Cluster unite for absorption/FFT/Group_4/Euclidean
# Cluster unite for absorption/FFT/Group_4/Braycurtis
# Cluster unite for absorption/FFT/Group_4/Canberra
# Cluster unite for absorption/FFT/Group_4/Chebyshev
# Cluster unite for absorption/FFT/Group_4/Cityblock
# Cluster unite for absorption/FFT/Group_4/Correlation
# Cluster unite for absorption/FFT/Group_4/Cosine
# Cluster unite for absorption/FFT/Group_4/Minkowski
# Cluster unite for absorption/FFT/Group_4/Hamming
# Cluster unite for absorption/FFT/Group_5/Euclidean
# Cluster unite for absorption/FFT/Group_5/Braycurtis
# Cluster unite for absorption/FFT/Group_5/Canberra
# Cluster unite for absorption/FFT/Group_5/Chebyshev
# Cluster unite for absorption/FFT/Group_5/Cityblock
# Cluster unite for absorption/FFT/Group_5/Correlation
# Cluster unite for absorption/FFT/Group_5/Cosine
# Cluster unite for absorption/FFT/Group_5/Minkowski
# Cluster unite for absorption/FFT/Group_5/Hamming
# Cluster unite for absorption/FFT/Group_6/Euclidean
# Cluster unite for absorption/FFT/Group_6/Braycurtis
# Cluster unite for absorption/FFT/Group_6/Canberra
# Cluster unite for absorption/FFT/Group_6/Chebyshev
# Cluster unite for absorption/FFT/Group_6/Cityblock
# Cluster unite for absorption/FFT/Group_6/Correlation
# Cluster unite for absorption/FFT/Group_6/Cosine
# Cluster unite for absorption/FFT/Group_6/Minkowski
# Cluster unite for absorption/FFT/Group_6/Hamming
# Cluster unite for absorption/FFT/Group_7/Euclidean
# Cluster unite for absorption/FFT/Group_7/Braycurtis
# Cluster unite for absorption/FFT/Group_7/Canberra
# Cluster unite for absorption/FFT/Group_7/Chebyshev
# Cluster unite for absorption/FFT/Group_7/Cityblock
# Cluster unite for absorption/FFT/Group_7/Correlation
# Cluster unite for absorption/FFT/Group_7/Cosine
# Cluster unite for absorption/FFT/Group_7/Minkowski
# Cluster unite for absorption/FFT/Group_7/Hamming
# Cluster unite for absorption/NLP/bepler/Euclidean
# Cluster unite for absorption/NLP/bepler/Braycurtis
# Cluster unite for absorption/NLP/bepler/Canberra
# Cluster unite for absorption/NLP/bepler/Chebyshev
# Cluster unite for absorption/NLP/bepler/Cityblock
# Cluster unite for absorption/NLP/bepler/Correlation
# Cluster unite for absorption/NLP/bepler/Cosine
# Cluster unite for absorption/NLP/bepler/Minkowski
# Cluster unite for absorption/NLP/bepler/Hamming
# Cluster unite for absorption/NLP/esm/Euclidean
# Cluster unite for absorption/NLP/esm/Braycurtis
# Cluster unite for absorption/NLP/esm/Canberra
# Cluster unite for absorption/NLP/esm/Chebyshev
# Cluster unite for absorption/NLP/esm/Cityblock
# Cluster unite for absorption/NLP/esm/Correlation
# Cluster unite for absorption/NLP/esm/Cosine
# Cluster unite for absorption/NLP/esm/Minkowski
# Cluster unite for absorption/NLP/esm/Hamming
# Cluster unite for absorption/NLP/fasttext/Euclidean
# Cluster unite for absorption/NLP/fasttext/Braycurtis
# Cluster unite for absorption/NLP/fasttext/Canberra
# Cluster unite for absorption/NLP/fasttext/Chebyshev
# Cluster unite for absorption/NLP/fasttext/Cityblock
# Cluster unite for absorption/NLP/fasttext/Correlation
# Cluster unite for absorption/NLP/fasttext/Cosine
# Cluster unite for absorption/NLP/fasttext/Minkowski
# Cluster unite for absorption/NLP/fasttext/Hamming
# Cluster unite for absorption/NLP/plus_rnn/Euclidean
# Cluster unite for absorption/NLP/plus_rnn/Braycurtis
# Cluster unite for absorption/NLP/plus_rnn/Canberra
# Cluster unite for absorption/NLP/plus_rnn/Chebyshev
# Cluster unite for absorption/NLP/plus_rnn/Cityblock
# Cluster unite for absorption/NLP/plus_rnn/Correlation
# Cluster unite for absorption/NLP/plus_rnn/Cosine
# Cluster unite for absorption/NLP/plus_rnn/Minkowski
# Cluster unite for absorption/NLP/plus_rnn/Hamming
# Cluster unite for absorption/NLP/prottrans/Euclidean
# Cluster unite for absorption/NLP/prottrans/Braycurtis
# Cluster unite for absorption/NLP/prottrans/Canberra
# Cluster unite for absorption/NLP/prottrans/Chebyshev
# Cluster unite for absorption/NLP/prottrans/Cityblock
# Cluster unite for absorption/NLP/prottrans/Correlation
# Cluster unite for absorption/NLP/prottrans/Cosine
# Cluster unite for absorption/NLP/prottrans/Minkowski
# Cluster unite for absorption/NLP/prottrans/Hamming
# Cluster unite for absorption/Properties/Group_0/Euclidean
# Cluster unite for absorption/Properties/Group_0/Braycurtis
# Cluster unite for absorption/Properties/Group_0/Canberra
# Cluster unite for absorption/Properties/Group_0/Chebyshev
# Cluster unite for absorption/Properties/Group_0/Cityblock
# Cluster unite for absorption/Properties/Group_0/Correlation
# Cluster unite for absorption/Properties/Group_0/Cosine
# Cluster unite for absorption/Properties/Group_0/Minkowski
# Cluster unite for absorption/Properties/Group_0/Hamming
# Cluster unite for absorption/Properties/Group_1/Euclidean
# Cluster unite for absorption/Properties/Group_1/Braycurtis
# Cluster unite for absorption/Properties/Group_1/Canberra
# Cluster unite for absorption/Properties/Group_1/Chebyshev
# Cluster unite for absorption/Properties/Group_1/Cityblock
# Cluster unite for absorption/Properties/Group_1/Correlation
# Cluster unite for absorption/Properties/Group_1/Cosine
# Cluster unite for absorption/Properties/Group_1/Minkowski
# Cluster unite for absorption/Properties/Group_1/Hamming
# Cluster unite for absorption/Properties/Group_2/Euclidean
# Cluster unite for absorption/Properties/Group_2/Braycurtis
# Cluster unite for absorption/Properties/Group_2/Canberra
# Cluster unite for absorption/Properties/Group_2/Chebyshev
# Cluster unite for absorption/Properties/Group_2/Cityblock
# Cluster unite for absorption/Properties/Group_2/Correlation
# Cluster unite for absorption/Properties/Group_2/Cosine
# Cluster unite for absorption/Properties/Group_2/Minkowski
# Cluster unite for absorption/Properties/Group_2/Hamming
# Cluster unite for absorption/Properties/Group_3/Euclidean
# Cluster unite for absorption/Properties/Group_3/Braycurtis
# Cluster unite for absorption/Properties/Group_3/Canberra
# Cluster unite for absorption/Properties/Group_3/Chebyshev
# Cluster unite for absorption/Properties/Group_3/Cityblock
# Cluster unite for absorption/Properties/Group_3/Correlation
# Cluster unite for absorption/Properties/Group_3/Cosine
# Cluster unite for absorption/Properties/Group_3/Minkowski
# Cluster unite for absorption/Properties/Group_3/Hamming
# Cluster unite for absorption/Properties/Group_4/Euclidean
# Cluster unite for absorption/Properties/Group_4/Braycurtis
# Cluster unite for absorption/Properties/Group_4/Canberra
# Cluster unite for absorption/Properties/Group_4/Chebyshev
# Cluster unite for absorption/Properties/Group_4/Cityblock
# Cluster unite for absorption/Properties/Group_4/Correlation
# Cluster unite for absorption/Properties/Group_4/Cosine
# Cluster unite for absorption/Properties/Group_4/Minkowski
# Cluster unite for absorption/Properties/Group_4/Hamming
# Cluster unite for absorption/Properties/Group_5/Euclidean
# Cluster unite for absorption/Properties/Group_5/Braycurtis
# Cluster unite for absorption/Properties/Group_5/Canberra
# Cluster unite for absorption/Properties/Group_5/Chebyshev
# Cluster unite for absorption/Properties/Group_5/Cityblock
# Cluster unite for absorption/Properties/Group_5/Correlation
# Cluster unite for absorption/Properties/Group_5/Cosine
# Cluster unite for absorption/Properties/Group_5/Minkowski
# Cluster unite for absorption/Properties/Group_5/Hamming
# Cluster unite for absorption/Properties/Group_6/Euclidean
# Cluster unite for absorption/Properties/Group_6/Braycurtis
# Cluster unite for absorption/Properties/Group_6/Canberra
# Cluster unite for absorption/Properties/Group_6/Chebyshev
# Cluster unite for absorption/Properties/Group_6/Cityblock
# Cluster unite for absorption/Properties/Group_6/Correlation
# Cluster unite for absorption/Properties/Group_6/Cosine
# Cluster unite for absorption/Properties/Group_6/Minkowski
# Cluster unite for absorption/Properties/Group_6/Hamming
# Cluster unite for absorption/Properties/Group_7/Euclidean
# Cluster unite for absorption/Properties/Group_7/Braycurtis
# Cluster unite for absorption/Properties/Group_7/Canberra
# Cluster unite for absorption/Properties/Group_7/Chebyshev
# Cluster unite for absorption/Properties/Group_7/Cityblock
# Cluster unite for absorption/Properties/Group_7/Correlation
# Cluster unite for absorption/Properties/Group_7/Cosine
# Cluster unite for absorption/Properties/Group_7/Minkowski
# Cluster unite for absorption/Properties/Group_7/Hamming
# Cluster unite for enantioselectivity/FFT/Group_0/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_0/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_0/Canberra
# Cluster unite for enantioselectivity/FFT/Group_0/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_0/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_0/Correlation
# Cluster unite for enantioselectivity/FFT/Group_0/Cosine
# Cluster unite for enantioselectivity/FFT/Group_0/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_0/Hamming
# Cluster unite for enantioselectivity/FFT/Group_1/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_1/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_1/Canberra
# Cluster unite for enantioselectivity/FFT/Group_1/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_1/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_1/Correlation
# Cluster unite for enantioselectivity/FFT/Group_1/Cosine
# Cluster unite for enantioselectivity/FFT/Group_1/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_1/Hamming
# Cluster unite for enantioselectivity/FFT/Group_2/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_2/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_2/Canberra
# Cluster unite for enantioselectivity/FFT/Group_2/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_2/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_2/Correlation
# Cluster unite for enantioselectivity/FFT/Group_2/Cosine
# Cluster unite for enantioselectivity/FFT/Group_2/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_2/Hamming
# Cluster unite for enantioselectivity/FFT/Group_3/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_3/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_3/Canberra
# Cluster unite for enantioselectivity/FFT/Group_3/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_3/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_3/Correlation
# Cluster unite for enantioselectivity/FFT/Group_3/Cosine
# Cluster unite for enantioselectivity/FFT/Group_3/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_3/Hamming
# Cluster unite for enantioselectivity/FFT/Group_4/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_4/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_4/Canberra
# Cluster unite for enantioselectivity/FFT/Group_4/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_4/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_4/Correlation
# Cluster unite for enantioselectivity/FFT/Group_4/Cosine
# Cluster unite for enantioselectivity/FFT/Group_4/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_4/Hamming
# Cluster unite for enantioselectivity/FFT/Group_5/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_5/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_5/Canberra
# Cluster unite for enantioselectivity/FFT/Group_5/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_5/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_5/Correlation
# Cluster unite for enantioselectivity/FFT/Group_5/Cosine
# Cluster unite for enantioselectivity/FFT/Group_5/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_5/Hamming
# Cluster unite for enantioselectivity/FFT/Group_6/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_6/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_6/Canberra
# Cluster unite for enantioselectivity/FFT/Group_6/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_6/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_6/Correlation
# Cluster unite for enantioselectivity/FFT/Group_6/Cosine
# Cluster unite for enantioselectivity/FFT/Group_6/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_6/Hamming
# Cluster unite for enantioselectivity/FFT/Group_7/Euclidean
# Cluster unite for enantioselectivity/FFT/Group_7/Braycurtis
# Cluster unite for enantioselectivity/FFT/Group_7/Canberra
# Cluster unite for enantioselectivity/FFT/Group_7/Chebyshev
# Cluster unite for enantioselectivity/FFT/Group_7/Cityblock
# Cluster unite for enantioselectivity/FFT/Group_7/Correlation
# Cluster unite for enantioselectivity/FFT/Group_7/Cosine
# Cluster unite for enantioselectivity/FFT/Group_7/Minkowski
# Cluster unite for enantioselectivity/FFT/Group_7/Hamming
# Cluster unite for enantioselectivity/NLP/bepler/Euclidean
# Cluster unite for enantioselectivity/NLP/bepler/Braycurtis
# Cluster unite for enantioselectivity/NLP/bepler/Canberra
# Cluster unite for enantioselectivity/NLP/bepler/Chebyshev
# Cluster unite for enantioselectivity/NLP/bepler/Cityblock
# Cluster unite for enantioselectivity/NLP/bepler/Correlation
# Cluster unite for enantioselectivity/NLP/bepler/Cosine
# Cluster unite for enantioselectivity/NLP/bepler/Minkowski
# Cluster unite for enantioselectivity/NLP/bepler/Hamming
# Cluster unite for enantioselectivity/NLP/esm/Euclidean
# Cluster unite for enantioselectivity/NLP/esm/Braycurtis
# Cluster unite for enantioselectivity/NLP/esm/Canberra
# Cluster unite for enantioselectivity/NLP/esm/Chebyshev
# Cluster unite for enantioselectivity/NLP/esm/Cityblock
# Cluster unite for enantioselectivity/NLP/esm/Correlation
# Cluster unite for enantioselectivity/NLP/esm/Cosine
# Cluster unite for enantioselectivity/NLP/esm/Minkowski
# Cluster unite for enantioselectivity/NLP/esm/Hamming
# Cluster unite for enantioselectivity/NLP/fasttext/Euclidean
# Cluster unite for enantioselectivity/NLP/fasttext/Braycurtis
# Cluster unite for enantioselectivity/NLP/fasttext/Canberra
# Cluster unite for enantioselectivity/NLP/fasttext/Chebyshev
# Cluster unite for enantioselectivity/NLP/fasttext/Cityblock
# Cluster unite for enantioselectivity/NLP/fasttext/Correlation
# Cluster unite for enantioselectivity/NLP/fasttext/Cosine
# Cluster unite for enantioselectivity/NLP/fasttext/Minkowski
# Cluster unite for enantioselectivity/NLP/fasttext/Hamming
# Cluster unite for enantioselectivity/NLP/plus_rnn/Euclidean
# Cluster unite for enantioselectivity/NLP/plus_rnn/Braycurtis
# Cluster unite for enantioselectivity/NLP/plus_rnn/Canberra
# Cluster unite for enantioselectivity/NLP/plus_rnn/Chebyshev
# Cluster unite for enantioselectivity/NLP/plus_rnn/Cityblock
# Cluster unite for enantioselectivity/NLP/plus_rnn/Correlation
# Cluster unite for enantioselectivity/NLP/plus_rnn/Cosine
# Cluster unite for enantioselectivity/NLP/plus_rnn/Minkowski
# Cluster unite for enantioselectivity/NLP/plus_rnn/Hamming
# Cluster unite for enantioselectivity/NLP/prottrans/Euclidean
# Cluster unite for enantioselectivity/NLP/prottrans/Braycurtis
# Cluster unite for enantioselectivity/NLP/prottrans/Canberra
# Cluster unite for enantioselectivity/NLP/prottrans/Chebyshev
# Cluster unite for enantioselectivity/NLP/prottrans/Cityblock
# Cluster unite for enantioselectivity/NLP/prottrans/Correlation
# Cluster unite for enantioselectivity/NLP/prottrans/Cosine
# Cluster unite for enantioselectivity/NLP/prottrans/Minkowski
# Cluster unite for enantioselectivity/NLP/prottrans/Hamming
# Cluster unite for enantioselectivity/Properties/Group_0/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_0/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_0/Canberra
# Cluster unite for enantioselectivity/Properties/Group_0/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_0/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_0/Correlation
# Cluster unite for enantioselectivity/Properties/Group_0/Cosine
# Cluster unite for enantioselectivity/Properties/Group_0/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_0/Hamming
# Cluster unite for enantioselectivity/Properties/Group_1/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_1/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_1/Canberra
# Cluster unite for enantioselectivity/Properties/Group_1/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_1/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_1/Correlation
# Cluster unite for enantioselectivity/Properties/Group_1/Cosine
# Cluster unite for enantioselectivity/Properties/Group_1/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_1/Hamming
# Cluster unite for enantioselectivity/Properties/Group_2/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_2/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_2/Canberra
# Cluster unite for enantioselectivity/Properties/Group_2/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_2/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_2/Correlation
# Cluster unite for enantioselectivity/Properties/Group_2/Cosine
# Cluster unite for enantioselectivity/Properties/Group_2/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_2/Hamming
# Cluster unite for enantioselectivity/Properties/Group_3/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_3/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_3/Canberra
# Cluster unite for enantioselectivity/Properties/Group_3/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_3/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_3/Correlation
# Cluster unite for enantioselectivity/Properties/Group_3/Cosine
# Cluster unite for enantioselectivity/Properties/Group_3/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_3/Hamming
# Cluster unite for enantioselectivity/Properties/Group_4/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_4/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_4/Canberra
# Cluster unite for enantioselectivity/Properties/Group_4/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_4/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_4/Correlation
# Cluster unite for enantioselectivity/Properties/Group_4/Cosine
# Cluster unite for enantioselectivity/Properties/Group_4/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_4/Hamming
# Cluster unite for enantioselectivity/Properties/Group_5/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_5/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_5/Canberra
# Cluster unite for enantioselectivity/Properties/Group_5/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_5/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_5/Correlation
# Cluster unite for enantioselectivity/Properties/Group_5/Cosine
# Cluster unite for enantioselectivity/Properties/Group_5/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_5/Hamming
# Cluster unite for enantioselectivity/Properties/Group_6/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_6/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_6/Canberra
# Cluster unite for enantioselectivity/Properties/Group_6/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_6/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_6/Correlation
# Cluster unite for enantioselectivity/Properties/Group_6/Cosine
# Cluster unite for enantioselectivity/Properties/Group_6/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_6/Hamming
# Cluster unite for enantioselectivity/Properties/Group_7/Euclidean
# Cluster unite for enantioselectivity/Properties/Group_7/Braycurtis
# Cluster unite for enantioselectivity/Properties/Group_7/Canberra
# Cluster unite for enantioselectivity/Properties/Group_7/Chebyshev
# Cluster unite for enantioselectivity/Properties/Group_7/Cityblock
# Cluster unite for enantioselectivity/Properties/Group_7/Correlation
# Cluster unite for enantioselectivity/Properties/Group_7/Cosine
# Cluster unite for enantioselectivity/Properties/Group_7/Minkowski
# Cluster unite for enantioselectivity/Properties/Group_7/Hamming
# Cluster unite for localization/FFT/Group_0/Euclidean
# Cluster unite for localization/FFT/Group_0/Braycurtis
# Cluster unite for localization/FFT/Group_0/Canberra
# Cluster unite for localization/FFT/Group_0/Chebyshev
# Cluster unite for localization/FFT/Group_0/Cityblock
# Cluster unite for localization/FFT/Group_0/Correlation
# Cluster unite for localization/FFT/Group_0/Cosine
# Cluster unite for localization/FFT/Group_0/Minkowski
# Cluster unite for localization/FFT/Group_0/Hamming
# Cluster unite for localization/FFT/Group_1/Euclidean
# Cluster unite for localization/FFT/Group_1/Braycurtis
# Cluster unite for localization/FFT/Group_1/Canberra
# Cluster unite for localization/FFT/Group_1/Chebyshev
# Cluster unite for localization/FFT/Group_1/Cityblock
# Cluster unite for localization/FFT/Group_1/Correlation
# Cluster unite for localization/FFT/Group_1/Cosine
# Cluster unite for localization/FFT/Group_1/Minkowski
# Cluster unite for localization/FFT/Group_1/Hamming
# Cluster unite for localization/FFT/Group_2/Euclidean
# Cluster unite for localization/FFT/Group_2/Braycurtis
# Cluster unite for localization/FFT/Group_2/Canberra
# Cluster unite for localization/FFT/Group_2/Chebyshev
# Cluster unite for localization/FFT/Group_2/Cityblock
# Cluster unite for localization/FFT/Group_2/Correlation
# Cluster unite for localization/FFT/Group_2/Cosine
# Cluster unite for localization/FFT/Group_2/Minkowski
# Cluster unite for localization/FFT/Group_2/Hamming
# Cluster unite for localization/FFT/Group_3/Euclidean
# Cluster unite for localization/FFT/Group_3/Braycurtis
# Cluster unite for localization/FFT/Group_3/Canberra
# Cluster unite for localization/FFT/Group_3/Chebyshev
# Cluster unite for localization/FFT/Group_3/Cityblock
# Cluster unite for localization/FFT/Group_3/Correlation
# Cluster unite for localization/FFT/Group_3/Cosine
# Cluster unite for localization/FFT/Group_3/Minkowski
# Cluster unite for localization/FFT/Group_3/Hamming
# Cluster unite for localization/FFT/Group_4/Euclidean
# Cluster unite for localization/FFT/Group_4/Braycurtis
# Cluster unite for localization/FFT/Group_4/Canberra
# Cluster unite for localization/FFT/Group_4/Chebyshev
# Cluster unite for localization/FFT/Group_4/Cityblock
# Cluster unite for localization/FFT/Group_4/Correlation
# Cluster unite for localization/FFT/Group_4/Cosine
# Cluster unite for localization/FFT/Group_4/Minkowski
# Cluster unite for localization/FFT/Group_4/Hamming
# Cluster unite for localization/FFT/Group_5/Euclidean
# Cluster unite for localization/FFT/Group_5/Braycurtis
# Cluster unite for localization/FFT/Group_5/Canberra
# Cluster unite for localization/FFT/Group_5/Chebyshev
# Cluster unite for localization/FFT/Group_5/Cityblock
# Cluster unite for localization/FFT/Group_5/Correlation
# Cluster unite for localization/FFT/Group_5/Cosine
# Cluster unite for localization/FFT/Group_5/Minkowski
# Cluster unite for localization/FFT/Group_5/Hamming
# Cluster unite for localization/FFT/Group_6/Euclidean
# Cluster unite for localization/FFT/Group_6/Braycurtis
# Cluster unite for localization/FFT/Group_6/Canberra
# Cluster unite for localization/FFT/Group_6/Chebyshev
# Cluster unite for localization/FFT/Group_6/Cityblock
# Cluster unite for localization/FFT/Group_6/Correlation
# Cluster unite for localization/FFT/Group_6/Cosine
# Cluster unite for localization/FFT/Group_6/Minkowski
# Cluster unite for localization/FFT/Group_6/Hamming
# Cluster unite for localization/FFT/Group_7/Euclidean
# Cluster unite for localization/FFT/Group_7/Braycurtis
# Cluster unite for localization/FFT/Group_7/Canberra
# Cluster unite for localization/FFT/Group_7/Chebyshev
# Cluster unite for localization/FFT/Group_7/Cityblock
# Cluster unite for localization/FFT/Group_7/Correlation
# Cluster unite for localization/FFT/Group_7/Cosine
# Cluster unite for localization/FFT/Group_7/Minkowski
# Cluster unite for localization/FFT/Group_7/Hamming
# Cluster unite for localization/NLP/bepler/Euclidean
# Cluster unite for localization/NLP/bepler/Braycurtis
# Cluster unite for localization/NLP/bepler/Canberra
# Cluster unite for localization/NLP/bepler/Chebyshev
# Cluster unite for localization/NLP/bepler/Cityblock
# Cluster unite for localization/NLP/bepler/Correlation
# Cluster unite for localization/NLP/bepler/Cosine
# Cluster unite for localization/NLP/bepler/Minkowski
# Cluster unite for localization/NLP/bepler/Hamming
# Cluster unite for localization/NLP/esm/Euclidean
# Cluster unite for localization/NLP/esm/Braycurtis
# Cluster unite for localization/NLP/esm/Canberra
# Cluster unite for localization/NLP/esm/Chebyshev
# Cluster unite for localization/NLP/esm/Cityblock
# Cluster unite for localization/NLP/esm/Correlation
# Cluster unite for localization/NLP/esm/Cosine
# Cluster unite for localization/NLP/esm/Minkowski
# Cluster unite for localization/NLP/esm/Hamming
# Cluster unite for localization/NLP/fasttext/Euclidean
# Cluster unite for localization/NLP/fasttext/Braycurtis
# Cluster unite for localization/NLP/fasttext/Canberra
# Cluster unite for localization/NLP/fasttext/Chebyshev
# Cluster unite for localization/NLP/fasttext/Cityblock
# Cluster unite for localization/NLP/fasttext/Correlation
# Cluster unite for localization/NLP/fasttext/Cosine
# Cluster unite for localization/NLP/fasttext/Minkowski
# Cluster unite for localization/NLP/fasttext/Hamming
# Cluster unite for localization/NLP/plus_rnn/Euclidean
# Cluster unite for localization/NLP/plus_rnn/Braycurtis
# Cluster unite for localization/NLP/plus_rnn/Canberra
# Cluster unite for localization/NLP/plus_rnn/Chebyshev
# Cluster unite for localization/NLP/plus_rnn/Cityblock
# Cluster unite for localization/NLP/plus_rnn/Correlation
# Cluster unite for localization/NLP/plus_rnn/Cosine
# Cluster unite for localization/NLP/plus_rnn/Minkowski
# Cluster unite for localization/NLP/plus_rnn/Hamming
# Cluster unite for localization/NLP/prottrans/Euclidean
# Cluster unite for localization/NLP/prottrans/Braycurtis
# Cluster unite for localization/NLP/prottrans/Canberra
# Cluster unite for localization/NLP/prottrans/Chebyshev
# Cluster unite for localization/NLP/prottrans/Cityblock
# Cluster unite for localization/NLP/prottrans/Correlation
# Cluster unite for localization/NLP/prottrans/Cosine
# Cluster unite for localization/NLP/prottrans/Minkowski
# Cluster unite for localization/NLP/prottrans/Hamming
# Cluster unite for localization/Properties/Group_0/Euclidean
# Cluster unite for localization/Properties/Group_0/Braycurtis
# Cluster unite for localization/Properties/Group_0/Canberra
# Cluster unite for localization/Properties/Group_0/Chebyshev
# Cluster unite for localization/Properties/Group_0/Cityblock
# Cluster unite for localization/Properties/Group_0/Correlation
# Cluster unite for localization/Properties/Group_0/Cosine
# Cluster unite for localization/Properties/Group_0/Minkowski
# Cluster unite for localization/Properties/Group_0/Hamming
# Cluster unite for localization/Properties/Group_1/Euclidean
# Cluster unite for localization/Properties/Group_1/Braycurtis
# Cluster unite for localization/Properties/Group_1/Canberra
# Cluster unite for localization/Properties/Group_1/Chebyshev
# Cluster unite for localization/Properties/Group_1/Cityblock
# Cluster unite for localization/Properties/Group_1/Correlation
# Cluster unite for localization/Properties/Group_1/Cosine
# Cluster unite for localization/Properties/Group_1/Minkowski
# Cluster unite for localization/Properties/Group_1/Hamming
# Cluster unite for localization/Properties/Group_2/Euclidean
# Cluster unite for localization/Properties/Group_2/Braycurtis
# Cluster unite for localization/Properties/Group_2/Canberra
# Cluster unite for localization/Properties/Group_2/Chebyshev
# Cluster unite for localization/Properties/Group_2/Cityblock
# Cluster unite for localization/Properties/Group_2/Correlation
# Cluster unite for localization/Properties/Group_2/Cosine
# Cluster unite for localization/Properties/Group_2/Minkowski
# Cluster unite for localization/Properties/Group_2/Hamming
# Cluster unite for localization/Properties/Group_3/Euclidean
# Cluster unite for localization/Properties/Group_3/Braycurtis
# Cluster unite for localization/Properties/Group_3/Canberra
# Cluster unite for localization/Properties/Group_3/Chebyshev
# Cluster unite for localization/Properties/Group_3/Cityblock
# Cluster unite for localization/Properties/Group_3/Correlation
# Cluster unite for localization/Properties/Group_3/Cosine
# Cluster unite for localization/Properties/Group_3/Minkowski
# Cluster unite for localization/Properties/Group_3/Hamming
# Cluster unite for localization/Properties/Group_4/Euclidean
# Cluster unite for localization/Properties/Group_4/Braycurtis
# Cluster unite for localization/Properties/Group_4/Canberra
# Cluster unite for localization/Properties/Group_4/Chebyshev
# Cluster unite for localization/Properties/Group_4/Cityblock
# Cluster unite for localization/Properties/Group_4/Correlation
# Cluster unite for localization/Properties/Group_4/Cosine
# Cluster unite for localization/Properties/Group_4/Minkowski
# Cluster unite for localization/Properties/Group_4/Hamming
# Cluster unite for localization/Properties/Group_5/Euclidean
# Cluster unite for localization/Properties/Group_5/Braycurtis
# Cluster unite for localization/Properties/Group_5/Canberra
# Cluster unite for localization/Properties/Group_5/Chebyshev
# Cluster unite for localization/Properties/Group_5/Cityblock
# Cluster unite for localization/Properties/Group_5/Correlation
# Cluster unite for localization/Properties/Group_5/Cosine
# Cluster unite for localization/Properties/Group_5/Minkowski
# Cluster unite for localization/Properties/Group_5/Hamming
# Cluster unite for localization/Properties/Group_6/Euclidean
# Cluster unite for localization/Properties/Group_6/Braycurtis
# Cluster unite for localization/Properties/Group_6/Canberra
# Cluster unite for localization/Properties/Group_6/Chebyshev
# Cluster unite for localization/Properties/Group_6/Cityblock
# Cluster unite for localization/Properties/Group_6/Correlation
# Cluster unite for localization/Properties/Group_6/Cosine
# Cluster unite for localization/Properties/Group_6/Minkowski
# Cluster unite for localization/Properties/Group_6/Hamming
# Cluster unite for localization/Properties/Group_7/Euclidean
# Cluster unite for localization/Properties/Group_7/Braycurtis
# Cluster unite for localization/Properties/Group_7/Canberra
# Cluster unite for localization/Properties/Group_7/Chebyshev
# Cluster unite for localization/Properties/Group_7/Cityblock
# Cluster unite for localization/Properties/Group_7/Correlation
# Cluster unite for localization/Properties/Group_7/Cosine
# Cluster unite for localization/Properties/Group_7/Minkowski
# Cluster unite for localization/Properties/Group_7/Hamming
# Cluster unite for T50/FFT/Group_0/Euclidean
# Cluster unite for T50/FFT/Group_0/Braycurtis
# Cluster unite for T50/FFT/Group_0/Canberra
# Cluster unite for T50/FFT/Group_0/Chebyshev
# Cluster unite for T50/FFT/Group_0/Cityblock
# Cluster unite for T50/FFT/Group_0/Correlation
# Cluster unite for T50/FFT/Group_0/Cosine
# Cluster unite for T50/FFT/Group_0/Minkowski
# Cluster unite for T50/FFT/Group_0/Hamming
# Cluster unite for T50/FFT/Group_1/Euclidean
# Cluster unite for T50/FFT/Group_1/Braycurtis
# Cluster unite for T50/FFT/Group_1/Canberra
# Cluster unite for T50/FFT/Group_1/Chebyshev
# Cluster unite for T50/FFT/Group_1/Cityblock
# Cluster unite for T50/FFT/Group_1/Correlation
# Cluster unite for T50/FFT/Group_1/Cosine
# Cluster unite for T50/FFT/Group_1/Minkowski
# Cluster unite for T50/FFT/Group_1/Hamming
# Cluster unite for T50/FFT/Group_2/Euclidean
# Cluster unite for T50/FFT/Group_2/Braycurtis
# Cluster unite for T50/FFT/Group_2/Canberra
# Cluster unite for T50/FFT/Group_2/Chebyshev
# Cluster unite for T50/FFT/Group_2/Cityblock
# Cluster unite for T50/FFT/Group_2/Correlation
# Cluster unite for T50/FFT/Group_2/Cosine
# Cluster unite for T50/FFT/Group_2/Minkowski
# Cluster unite for T50/FFT/Group_2/Hamming
# Cluster unite for T50/FFT/Group_3/Euclidean
# Cluster unite for T50/FFT/Group_3/Braycurtis
# Cluster unite for T50/FFT/Group_3/Canberra
# Cluster unite for T50/FFT/Group_3/Chebyshev
# Cluster unite for T50/FFT/Group_3/Cityblock
# Cluster unite for T50/FFT/Group_3/Correlation
# Cluster unite for T50/FFT/Group_3/Cosine
# Cluster unite for T50/FFT/Group_3/Minkowski
# Cluster unite for T50/FFT/Group_3/Hamming
# Cluster unite for T50/FFT/Group_4/Euclidean
# Cluster unite for T50/FFT/Group_4/Braycurtis
# Cluster unite for T50/FFT/Group_4/Canberra
# Cluster unite for T50/FFT/Group_4/Chebyshev
# Cluster unite for T50/FFT/Group_4/Cityblock
# Cluster unite for T50/FFT/Group_4/Correlation
# Cluster unite for T50/FFT/Group_4/Cosine
# Cluster unite for T50/FFT/Group_4/Minkowski
# Cluster unite for T50/FFT/Group_4/Hamming
# Cluster unite for T50/FFT/Group_5/Euclidean
# Cluster unite for T50/FFT/Group_5/Braycurtis
# Cluster unite for T50/FFT/Group_5/Canberra
# Cluster unite for T50/FFT/Group_5/Chebyshev
# Cluster unite for T50/FFT/Group_5/Cityblock
# Cluster unite for T50/FFT/Group_5/Correlation
# Cluster unite for T50/FFT/Group_5/Cosine
# Cluster unite for T50/FFT/Group_5/Minkowski
# Cluster unite for T50/FFT/Group_5/Hamming
# Cluster unite for T50/FFT/Group_6/Euclidean
# Cluster unite for T50/FFT/Group_6/Braycurtis
# Cluster unite for T50/FFT/Group_6/Canberra
# Cluster unite for T50/FFT/Group_6/Chebyshev
# Cluster unite for T50/FFT/Group_6/Cityblock
# Cluster unite for T50/FFT/Group_6/Correlation
# Cluster unite for T50/FFT/Group_6/Cosine
# Cluster unite for T50/FFT/Group_6/Minkowski
# Cluster unite for T50/FFT/Group_6/Hamming
# Cluster unite for T50/FFT/Group_7/Euclidean
# Cluster unite for T50/FFT/Group_7/Braycurtis
# Cluster unite for T50/FFT/Group_7/Canberra
# Cluster unite for T50/FFT/Group_7/Chebyshev
# Cluster unite for T50/FFT/Group_7/Cityblock
# Cluster unite for T50/FFT/Group_7/Correlation
# Cluster unite for T50/FFT/Group_7/Cosine
# Cluster unite for T50/FFT/Group_7/Minkowski
# Cluster unite for T50/FFT/Group_7/Hamming
# Cluster unite for T50/NLP/bepler/Euclidean
# Cluster unite for T50/NLP/bepler/Braycurtis
# Cluster unite for T50/NLP/bepler/Canberra
# Cluster unite for T50/NLP/bepler/Chebyshev
# Cluster unite for T50/NLP/bepler/Cityblock
# Cluster unite for T50/NLP/bepler/Correlation
# Cluster unite for T50/NLP/bepler/Cosine
# Cluster unite for T50/NLP/bepler/Minkowski
# Cluster unite for T50/NLP/bepler/Hamming
# Cluster unite for T50/NLP/esm/Euclidean
# Cluster unite for T50/NLP/esm/Braycurtis
# Cluster unite for T50/NLP/esm/Canberra
# Cluster unite for T50/NLP/esm/Chebyshev
# Cluster unite for T50/NLP/esm/Cityblock
# Cluster unite for T50/NLP/esm/Correlation
# Cluster unite for T50/NLP/esm/Cosine
# Cluster unite for T50/NLP/esm/Minkowski
# Cluster unite for T50/NLP/esm/Hamming
# Cluster unite for T50/NLP/fasttext/Euclidean
# Cluster unite for T50/NLP/fasttext/Braycurtis
# Cluster unite for T50/NLP/fasttext/Canberra
# Cluster unite for T50/NLP/fasttext/Chebyshev
# Cluster unite for T50/NLP/fasttext/Cityblock
# Cluster unite for T50/NLP/fasttext/Correlation
# Cluster unite for T50/NLP/fasttext/Cosine
# Cluster unite for T50/NLP/fasttext/Minkowski
# Cluster unite for T50/NLP/fasttext/Hamming
# Cluster unite for T50/NLP/plus_rnn/Euclidean
# Cluster unite for T50/NLP/plus_rnn/Braycurtis
# Cluster unite for T50/NLP/plus_rnn/Canberra
# Cluster unite for T50/NLP/plus_rnn/Chebyshev
# Cluster unite for T50/NLP/plus_rnn/Cityblock
# Cluster unite for T50/NLP/plus_rnn/Correlation
# Cluster unite for T50/NLP/plus_rnn/Cosine
# Cluster unite for T50/NLP/plus_rnn/Minkowski
# Cluster unite for T50/NLP/plus_rnn/Hamming
# Cluster unite for T50/NLP/prottrans/Euclidean
# Cluster unite for T50/NLP/prottrans/Braycurtis
# Cluster unite for T50/NLP/prottrans/Canberra
# Cluster unite for T50/NLP/prottrans/Chebyshev
# Cluster unite for T50/NLP/prottrans/Cityblock
# Cluster unite for T50/NLP/prottrans/Correlation
# Cluster unite for T50/NLP/prottrans/Cosine
# Cluster unite for T50/NLP/prottrans/Minkowski
# Cluster unite for T50/NLP/prottrans/Hamming
# Cluster unite for T50/Properties/Group_0/Euclidean
# Cluster unite for T50/Properties/Group_0/Braycurtis
# Cluster unite for T50/Properties/Group_0/Canberra
# Cluster unite for T50/Properties/Group_0/Chebyshev
# Cluster unite for T50/Properties/Group_0/Cityblock
# Cluster unite for T50/Properties/Group_0/Correlation
# Cluster unite for T50/Properties/Group_0/Cosine
# Cluster unite for T50/Properties/Group_0/Minkowski
# Cluster unite for T50/Properties/Group_0/Hamming
# Cluster unite for T50/Properties/Group_1/Euclidean
# Cluster unite for T50/Properties/Group_1/Braycurtis
# Cluster unite for T50/Properties/Group_1/Canberra
# Cluster unite for T50/Properties/Group_1/Chebyshev
# Cluster unite for T50/Properties/Group_1/Cityblock
# Cluster unite for T50/Properties/Group_1/Correlation
# Cluster unite for T50/Properties/Group_1/Cosine
# Cluster unite for T50/Properties/Group_1/Minkowski
# Cluster unite for T50/Properties/Group_1/Hamming
# Cluster unite for T50/Properties/Group_2/Euclidean
# Cluster unite for T50/Properties/Group_2/Braycurtis
# Cluster unite for T50/Properties/Group_2/Canberra
# Cluster unite for T50/Properties/Group_2/Chebyshev
# Cluster unite for T50/Properties/Group_2/Cityblock
# Cluster unite for T50/Properties/Group_2/Correlation
# Cluster unite for T50/Properties/Group_2/Cosine
# Cluster unite for T50/Properties/Group_2/Minkowski
# Cluster unite for T50/Properties/Group_2/Hamming
# Cluster unite for T50/Properties/Group_3/Euclidean
# Cluster unite for T50/Properties/Group_3/Braycurtis
# Cluster unite for T50/Properties/Group_3/Canberra
# Cluster unite for T50/Properties/Group_3/Chebyshev
# Cluster unite for T50/Properties/Group_3/Cityblock
# Cluster unite for T50/Properties/Group_3/Correlation
# Cluster unite for T50/Properties/Group_3/Cosine
# Cluster unite for T50/Properties/Group_3/Minkowski
# Cluster unite for T50/Properties/Group_3/Hamming
# Cluster unite for T50/Properties/Group_4/Euclidean
# Cluster unite for T50/Properties/Group_4/Braycurtis
# Cluster unite for T50/Properties/Group_4/Canberra
# Cluster unite for T50/Properties/Group_4/Chebyshev
# Cluster unite for T50/Properties/Group_4/Cityblock
# Cluster unite for T50/Properties/Group_4/Correlation
# Cluster unite for T50/Properties/Group_4/Cosine
# Cluster unite for T50/Properties/Group_4/Minkowski
# Cluster unite for T50/Properties/Group_4/Hamming
# Cluster unite for T50/Properties/Group_5/Euclidean
# Cluster unite for T50/Properties/Group_5/Braycurtis
# Cluster unite for T50/Properties/Group_5/Canberra
# Cluster unite for T50/Properties/Group_5/Chebyshev
# Cluster unite for T50/Properties/Group_5/Cityblock
# Cluster unite for T50/Properties/Group_5/Correlation
# Cluster unite for T50/Properties/Group_5/Cosine
# Cluster unite for T50/Properties/Group_5/Minkowski
# Cluster unite for T50/Properties/Group_5/Hamming
# Cluster unite for T50/Properties/Group_6/Euclidean
# Cluster unite for T50/Properties/Group_6/Braycurtis
# Cluster unite for T50/Properties/Group_6/Canberra
# Cluster unite for T50/Properties/Group_6/Chebyshev
# Cluster unite for T50/Properties/Group_6/Cityblock
# Cluster unite for T50/Properties/Group_6/Correlation
# Cluster unite for T50/Properties/Group_6/Cosine
# Cluster unite for T50/Properties/Group_6/Minkowski
# Cluster unite for T50/Properties/Group_6/Hamming
# Cluster unite for T50/Properties/Group_7/Euclidean
# Cluster unite for T50/Properties/Group_7/Braycurtis
# Cluster unite for T50/Properties/Group_7/Canberra
# Cluster unite for T50/Properties/Group_7/Chebyshev
# Cluster unite for T50/Properties/Group_7/Cityblock
# Cluster unite for T50/Properties/Group_7/Correlation
# Cluster unite for T50/Properties/Group_7/Cosine
# Cluster unite for T50/Properties/Group_7/Minkowski
# Cluster unite for T50/Properties/Group_7/Hamming
